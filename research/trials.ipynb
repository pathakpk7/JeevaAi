# %%
print("ok")
# Out:
# ok

# %%
# %pwd
# Out:
# 'D:\\Langchain-Project\\End-to-End-Medical-Chatbot-Generative-AI'

# %%
# %pwd
# Out:
# 'D:\\Langchain-Project\\End-to-End-Medical-Chatbot-Generative-AI'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'D:\\Langchain-Project'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'D:\\'

# %%
import os
os.chdir("./")

# %%
# %pwd
# Out:
# 'D:\\'

# %%
import os
os.chdir(r"D:\Langchain-Project\End-to-End-Medical-Chatbot-Generative-AI")
print(os.getcwd())
# Out:
# D:\Langchain-Project\End-to-End-Medical-Chatbot-Generative-AI

# %%
# %pwd
# Out:
# 'D:\\Langchain-Project\\End-to-End-Medical-Chatbot-Generative-AI'

# %%
from pathlib import Path
import os
# go to parent (one level up)
os.chdir(Path.cwd().parent)
print(Path.cwd())
# — or set explicitly —
os.chdir(Path(r"D:\Langchain-Project\End-to-End-Medical-Chatbot-Generative-AI"))
print(Path.cwd())

# %pwd
# Out:
# D:\Langchain-Project
# D:\Langchain-Project\End-to-End-Medical-Chatbot-Generative-AI
# 'D:\\Langchain-Project\\End-to-End-Medical-Chatbot-Generative-AI'

# %%
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
#Extracting text from PDF files in a directory
def load_pdf_file(data):
    loader = DirectoryLoader(data, 
                            glob="**/*.pdf",
                            loader_cls=PyPDFLoader)
    documents = loader.load()
    return documents

# %%
extracted_data=load_pdf_file(data='Data/' )

# %%
#split the data into text chunks

def split_text(extracted_data):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=500,
        chunk_overlap=20,)
    text_chunk=text_splitter.split_documents(extracted_data)
    return text_chunk

# %%
text_chunk=split_text(extracted_data)
print(f"Number of text chunks: {len(text_chunk)}")
# Out:
# Number of text chunks: 6973

# %%
from langchain.embeddings import HuggingFaceBgeEmbeddings

# %%
#Download the model and create embeddings

def download_hugging_face_embeddings():
    embeddings = HuggingFaceBgeEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
    return embeddings 
#this embedding model     model_name='sentence-transformers/all-MiniLM-L6-v2'     provides the 384 dimensional dense space and can be used for tasks like clustering or semantic search.

# %%
# %pip install sentence-transformers

# Make sure cell 18 is executed before running this cell

embeddings = download_hugging_face_embeddings()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\patha\miniconda3\envs\medibot\lib\site-packages\langchain_community\embeddings\huggingface.py:330, in HuggingFaceBgeEmbeddings.__init__(self, **kwargs)
#     329 try:
# --> 330     import sentence_transformers
#     332 except ImportError as exc:
#
# File c:\Users\patha\miniconda3\envs\medibot\lib\site-packages\sentence_transformers\__init__.py:3
#       2 __MODEL_HUB_ORGANIZATION__ = 'sentence-transformers'
# ----> 3 from .datasets import SentencesDataset, ParallelSentencesDataset
#       4 from .LoggingHandler import LoggingHandler
#
# File c:\Users\patha\miniconda3\envs\medibot\lib\site-packages\sentence_transformers\datasets\__init__.py:3
#       2 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ...

# %%
embeddings = download_hugging_face_embeddings()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\patha\miniconda3\envs\medibot\lib\site-packages\langchain_community\embeddings\huggingface.py:330, in HuggingFaceBgeEmbeddings.__init__(self, **kwargs)
#     329 try:
# --> 330     import sentence_transformers
#     332 except ImportError as exc:
#
# File c:\Users\patha\miniconda3\envs\medibot\lib\site-packages\sentence_transformers\__init__.py:3
#       2 __MODEL_HUB_ORGANIZATION__ = 'sentence-transformers'
# ----> 3 from .datasets import SentencesDataset, ParallelSentencesDataset
#       4 from .LoggingHandler import LoggingHandler
#
# File c:\Users\patha\miniconda3\envs\medibot\lib\site-packages\sentence_transformers\datasets\__init__.py:3
#       2 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ----> 3 from .ParallelSentencesDataset import ParallelSentencesDataset
# ...
